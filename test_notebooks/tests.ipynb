# %%
import os
from dotenv import load_dotenv

# Load the variables from the .env file into the environment
load_dotenv()

# Access the variables using os.getenv()
DB_URL = None

if DB_URL is None:
    print("DB_URL not found")
else:
    print("db url is found")
# Out:
# DB_URL not found

# %%
import logging
import os
from pathlib import Path

import pandas as pd
from dotenv import load_dotenv
from supabase import create_client, Client

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s",
)
logger = logging.getLogger(__name__)

CSV_PATH = Path(__file__).parent / "Addresses.csv"  # always relative to THIS file
SCHEMA = "bronze"
TABLE = "erp_addresses"
BATCH_SIZE = 500  # rows per upsert request — tune based on row width

RENAME_MAP = {
    "ADDRESSID": "address_id",
    "CITY": "city",
    "POSTALCODE": "postal_code",          # fixed typo: 'posta_code' -> 'postal_code'
    "STREET": "street",
    "BUILDING": "building",
    "COUNTRY": "country",
    "REGION": "region",
    "ADDRESSTYPE": "address_type",
    "VALIDITY_STARTDATE": "validity_start_date",
    "VALIDITY_ENDDATE": "validity_end_date",
    "LATITUDE": "latitude",
    "LONGITUDE": "longitude",             # fixed typo: 'longitiude' -> 'longitude'
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 15
#      11     format="%(asctime)s [%(levelname)s] %(message)s",
#      12 )
#      13 logger = logging.getLogger(__name__)
#      14
# ---> 15 CSV_PATH = Path(__file__).parent / "Addresses.csv"  # always relative to THIS file
#      16 SCHEMA = "bronze"
#      17 TABLE = "erp_addresses"
#      18 BATCH_SIZE = 500  # rows per upsert request — tune based on row width
#
# NameError: name '__file__' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 print(__file__)
#
# NameError: name '__file__' is not defined

# %%
from datetime import datetime

x = datetime(2001 , 2 , 5)

# %%
print(x)
# Out:
# 2001-02-05 00:00:00
